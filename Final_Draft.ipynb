# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas import DataFrame
import seaborn as sns
import os

# %%
songdata_df = DataFrame(pd.read_csv("song_data.csv", index_col = 0))
songinfo_df = DataFrame(pd.read_csv("song_info.csv", index_col = 0))

# %%
songdata_df.head()
# Out:
#                             song_popularity  song_duration_ms  acousticness  \
# song_name
# Boulevard of Broken Dreams               73            262333      0.005520
# In The End                               66            216933      0.010300
# Seven Nation Army                        76            231733      0.008170
# By The Way                               74            216933      0.026400
# How You Remind Me                        56            223826      0.000954
#
#                             danceability  energy  instrumentalness  key  \
# song_name
# Boulevard of Broken Dreams         0.496   0.682          0.000029    8
# In The End                         0.542   0.853          0.000000    3
# Seven Nation Army                  0.737   0.463          0.447000    0
# By The Way                         0.451   0.970          0.003550    0
# How You Remind Me                  0.447   0.766          0.000000   10
#
#                             liveness  loudness  audio_mode  speechiness  \
# song_name
# Boulevard of Broken Dreams    0.0589    -4.095           1       0.0294
# In The End                    0.1080    -6.407           0       0.0498
# Seven Nation Army             0.2550    -7.828           1       0.0792
# By The Way                    0.1020    -4.938           1       0.1070
# How You Remind Me             0.1130    -5.065           1       0.0313
#
#                               tempo  time_signature  audio_valence
# song_name
# Boulevard of Broken Dreams  167.060               4          0.474
# In The End                  105.256               4          0.370
# Seven Nation Army           123.881               4          0.324
# By The Way                  122.444               4          0.198
# How You Remind Me           172.011               4          0.574

# %%
songinfo_df.head()
# Out:
#                                       artist_name  \
# song_name
# Boulevard of Broken Dreams              Green Day
# In The End                            Linkin Park
# Seven Nation Army               The White Stripes
# By The Way                  Red Hot Chili Peppers
# How You Remind Me                      Nickelback
#
#                                                    album_names  \
# song_name
# Boulevard of Broken Dreams  Greatest Hits: God's Favorite Band
# In The End                                       Hybrid Theory
# Seven Nation Army                                     Elephant
# By The Way                         By The Way (Deluxe Version)
# How You Remind Me                               Silver Side Up
#
#                                     playlist
# song_name
# Boulevard of Broken Dreams  00s Rock Anthems
# In The End                  00s Rock Anthems
# Seven Nation Army           00s Rock Anthems
# By The Way                  00s Rock Anthems
# How You Remind Me           00s Rock Anthems

# %%
songs_df = pd.concat([songdata_df, songinfo_df], axis=1)

# %%
songs_df.head()
# Out:
#                             song_popularity  song_duration_ms  acousticness  \
# song_name
# Boulevard of Broken Dreams               73            262333      0.005520
# In The End                               66            216933      0.010300
# Seven Nation Army                        76            231733      0.008170
# By The Way                               74            216933      0.026400
# How You Remind Me                        56            223826      0.000954
#
#                             danceability  energy  instrumentalness  key  \
# song_name
# Boulevard of Broken Dreams         0.496   0.682          0.000029    8
# In The End                         0.542   0.853          0.000000    3
# Seven Nation Army                  0.737   0.463          0.447000    0
# By The Way                         0.451   0.970          0.003550    0
# How You Remind Me                  0.447   0.766          0.000000   10
#
#                             liveness  loudness  audio_mode  speechiness  \
# song_name
# Boulevard of Broken Dreams    0.0589    -4.095           1       0.0294
# In The End                    0.1080    -6.407           0       0.0498
# Seven Nation Army             0.2550    -7.828           1       0.0792
# By The Way                    0.1020    -4.938           1       0.1070
# How You Remind Me             0.1130    -5.065           1       0.0313
#
#                               tempo  time_signature  audio_valence  \
# song_name
# Boulevard of Broken Dreams  167.060               4          0.474
# In The End                  105.256               4          0.370
# Seven Nation Army           123.881               4          0.324
# By The Way                  122.444               4          0.198
# How You Remind Me           172.011               4          0.574
#
#                                       artist_name  \
# song_name
# Boulevard of Broken Dreams              Green Day
# In The End                            Linkin Park
# Seven Nation Army               The White Stripes
# By The Way                  Red Hot Chili Peppers
# How You Remind Me                      Nickelback
#
#                                                    album_names  \
# song_name
# Boulevard of Broken Dreams  Greatest Hits: God's Favorite Band
# In The End                                       Hybrid Theory
# Seven Nation Army                                     Elephant
# By The Way                         By The Way (Deluxe Version)
# How You Remind Me                               Silver Side Up
#
#                                     playlist
# song_name
# Boulevard of Broken Dreams  00s Rock Anthems
# In The End                  00s Rock Anthems
# Seven Nation Army           00s Rock Anthems
# By The Way                  00s Rock Anthems
# How You Remind Me           00s Rock Anthems

# %% [markdown]
# **Song Popularity**
#
# The popularity of an artist's track relative to the rest of their discography. The value will be between 0 and 100, with 100 being the most popular.
# The popularity of a track is a value between 0 and 100, with 100 being the most popular. The popularity is calculated by algorithm and is based, in the most part, on the total number of plays the track has had and how recent those plays are.
#
# **Song Duration (ms)**
#
# Contains data on the length of time the song is in milliseconds
#
# **Acousticness**
#
# A measurement from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents highest confidence the track is acoustic.
#
# **Danceability**
#
# Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of type float is returned between 0.0 and 1.0, where 0.0 is least danceable and 1.0 is most danceable.
#
# **Energy**
#
# Energy is a measure of type float that is between 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Energetic tracks can be described as fast, loud, and noisy. For example, death metal has high energy, while a slow jazz would register low on the scale.
#
# **Instrumentalness**
#
# Predicts whether a track contains no vocals by returning a value of type float that is between 0.0 and 1.0. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#
# **Liveness**
#
# Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#
#
# **Loudness**
#
# The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db
#
# **Audio Mode**
#
# Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#
# **Speechiness**
#
# Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#
# **Tempo**
#
# The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# **Time Signature**
#
# An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure).
#
# **Key Signature**
#
# Key signature is represented on a scale, where integers are mapped to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on.
#
# **Audio Valence**
#
# A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# **Artist Name**
#
# Artist that wrote the song
#
# **ALbum Names**
# Album that the song was released on
#
# **Playlist**
# Playlist that song originates from. **Note: Some songs may be part of multiple playlists**

# %%
songs_df.columns.values
# Out:
# array(['song_popularity', 'song_duration_ms', 'acousticness',
#        'danceability', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'audio_mode', 'speechiness', 'tempo', 'time_signature',
#        'audio_valence', 'artist_name', 'album_names', 'playlist'],
#       dtype=object)

# %%
playlist_sizes = DataFrame(songs_df.playlist.value_counts())

# %%
for i in playlist_sizes.index:
    print(i)
# Out:
# NTC_ Gym Strong
# Country's Greatest Hits_  The '90s
# The GRAMMYs Official Playlist
# You & Me
# New Music Friday
# Have a Great Day!
# Low-Key
# Alternative 80s
# Feelin' Good
# All Out 80s
# Lush Lofi
# Soak Up the Sun
# Chill Instrumental Beats
# Country's Greatest Hits_  The '80s
# Off the Strength
# Workday_ Pop
# Nike Running Tempo Mix
# Piano in the Background
# Soft Pop Hits
# 80s Rock Anthems
# Persian Essentials
# NTC_ High Intensity Training Tracks
# Infinite Acoustic
# Mellow Bars
# Alternative 10s
# Most Necessary
# Retro Pop
# The Realest Down South
# Young & Free
# Cali Fire
# 90s Pop Rock Essentials
# One-Hit Wonders
# NTC_ Studio Sounds
# Alternative 90s
# Feel-Good Indie Rock
# Acoustic Covers
# Indie Workout
# 80s Hard Rock
# All Out 00s
# 70s Rock Anthems
# All Out 90s
# 60s Rock Anthems
# Country's Greatest Hits_  The '70's
# Your Favorite Coffeehouse
# Happy Folk
# Acoustic Hits
# I Love My '90s Hip-Hop
# Rockin' Vibes
# Contemporary Blend
# Country's Greatest Hits_  The '60s
# Get Turnt
# Guilty Pleasures
# It's ALT Good!
# Bedroom Pop
# Signed XOXO
# Country's Greatest Hits_  The '50s
# All Out 70s
# All Out 60s
# Swagger
# Songs to Sing in the Car
# Pumping Iron
# One More Rep
# Autumn Leaves
# K-Hip-Hop Beats
# Early Alternative
# Wake Up Happy
# Cool Down
# Stay Wild
# Rock Me UP!
# Ill Lyricist
# Rap UK
# Mood Booster
# Soul Coffee
# Abuela's Mix
# Alternative 00s
# A Perfect Day
# 80s Smash Hits
# Grime Instrumentals
# 2000s Smash Hits
# The '80s All Lined Up
# The Most Beautiful Songs in the World
# Alternative 70s
# Alternative 60s
# Songs to Sing in the Shower
# Latin Pride
# Pop Rising
# NIKE RUNNING FASTEST MILE
# Weekend Hangouts
# Hard Rock Workout
# Mega Hit Mix
# All Out 50s
# Punk Rock Workout
# 90's Hip-Hop Don't Stop
# Good Vibes
# Way Back Workout
# Calm Vibes
# The Piano Lounge
# Jock Jams
# Fresh Finds
# The Birth of Rhythm & Blues
# Pop Royalty
# LADY GAGA  JOANNE
# Radio 1 Playlist (BBC)
# Big Gains Workout
# Down In The Dumps
# We Everywhere
# This Is A$AP Mob
# Fit & Smiling
# African Heat
# Pumped Pop
# Warrior Workout
# Boogaloo Essentials
# Corre con Rock
# Chinese Hip-Hop Stars
# Spin Class
# Born in the USA
# Spin Fit
# Indie Sunshine
# Represent_ Guatemala
# Power Run 145 BPM
# Wa-oh-wa-oh!
# Represent_ Puerto Rico
# Ultimate Pump Up
# If It Wasn't For Gucci
# Fresh Finds_ Fire Emoji
# Viral Hits
# Workout Groove
# For Puerto Rico Por Puerto Rico
# Rhythm & Dance
# Wake Up Sweating
# Represent_ Cuba
# Represent_ Colombia
# Latina Power_ Jackie Cruz
# The Britney Body Workout
# Represent_ Brazil
# Get Your Body Right
# Represent_ Dominican Republic
# Feeling Accomplished
# Fangirls Run the World
# Represent_ Mexico
# Fresh Finds_ Poptronix
# Skylar Diggins' Training Mix

# %% [markdown]
# Above we've counted how many playlists there are within our data. From first glancing at the available playlist names, it seems pretty straightforward that we can subset genres by the titles of the playlists. An example of this is below. We create a dataframe solely with playlists in the rock genre, and as we can see, we have a collection of rock music. We do this for other common genres.

# %%
#Create Rock data frame
rock_df = songs_df[songs_df['playlist'].str.contains("Rock")]
rock_df.insert(rock_df.shape[1], "Genre", "Rock", True)

# %%
rock_df.playlist.value_counts()
# Out:
# Rockin' Vibes              100
# 90s Pop Rock Essentials    100
# 80s Rock Anthems           100
# 80s Hard Rock              100
# 60s Rock Anthems           100
# 70s Rock Anthems           100
# Feel-Good Indie Rock       100
# Rock Me UP!                 85
# Hard Rock Workout           76
# Punk Rock Workout           75
# 00s Rock Anthems            60
# Rock Your Body              51
# Rock This                   50
# 90s Rock Anthems            50
# Corre con Rock              30
# Name: playlist, dtype: int64

# %%
rock_df.shape
# Out:
# (1177, 18)

# %%
#Create Country DataFrame
country_df = songs_df[songs_df['playlist'].str.contains("Country")]
country_df.insert(country_df.shape[1], "Genre", "Country", True)
country_df.shape
# Out:
# (674, 18)

# %%
#Create pop dataframe
pop_df = songs_df[songs_df['playlist'].str.contains("Pop")]
pop_df.insert(pop_df.shape[1], "Genre", "Pop", True)
pop_df.shape
# Out:
# (1222, 18)

# %%
#Collect playlists from rap and hip hop
rap_df = songs_df[(songs_df['playlist'].str.contains("Rap")) | (songs_df['playlist'].str.contains("Hop")) ]
rap_df.insert(rap_df.shape[1], "Genre", "Rap", True)
rap_df.shape
# Out:
# (987, 18)

# %%
#Alternative
alt_df = songs_df[songs_df['playlist'].str.contains("Alternative")]
alt_df.insert(alt_df.shape[1], "Genre", "Alternative", True)
alt_df.shape
# Out:
# (689, 18)

# %%
#Electronic
electronic_df = songs_df[ (songs_df['playlist'].str.contains("House")) | (songs_df['playlist'].str.contains("Instrumental")) | (songs_df['playlist'].str.contains("Chill"))]
electronic_df.insert(electronic_df.shape[1], "Genre", "Electronic", True)
electronic_df.shape
# Out:
# (352, 18)

# %%
#Latin music
latin_df = songs_df[(songs_df['playlist'].str.contains("Latin")) | 
                    (songs_df['playlist'].str.contains("Mex")) | 
                    (songs_df['playlist'].str.contains("Columbia")) | 
                    (songs_df['playlist'].str.contains("Puerto")) | 
                    (songs_df['playlist'].str.contains("Brazil")) | 
                    (songs_df['playlist'].str.contains("Salsa")) | 
                    (songs_df['playlist'].str.contains("Bachata")) | 
                    (songs_df['playlist'].str.contains("Regg")) | 
                    (songs_df['playlist'].str.contains("Chicano"))]
latin_df.insert(latin_df.shape[1], "Genre", "Latin", True)
latin_df.shape
# Out:
# (1094, 18)

# %%
#new_songs_df = pd.concat(latin_df,indie_df, keys=['latin_df', 'indie_df', 'alt_df','rap_df','pop_df','country_df'])
#dfs = [df0, df1, df2, dfN]
all_genres_df=pd.concat([latin_df, electronic_df,alt_df,rap_df,pop_df,country_df,rock_df])
all_genres_df.shape
# Out:
# (6195, 18)

# %%
all_genres_df
# Out:
#                                                     song_popularity  \
# song_name
# MIA (feat. Drake)                                                94
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)                   98
# White Boi                                                        59
# Just Wanna Love You (feat. J. Balvin)                            73
# Beautiful (feat. Camila Cabello)                                 94
# Celoso                                                           87
# Good Vibes                                                       73
# Real Friends                                                     85
# Pa La Calle                                                      61
# Pa Mí                                                            58
# Wake Up in the Sky                                               92
# Está Rico                                                        83
# Banana Clip - Spanish Version                                    57
# YAKWTFGO (feat. Kali Uchis)                                      44
# Come With Me                                                     47
# Como Si Na                                                       54
# Blah                                                             47
# Love N Hennessy REMIX (feat. 2 Chainz & Nicky Jam)               64
# Mi Infinita                                                      56
# Coqueta                                                          49
# Sola                                                             65
# Nuestro Planeta (feat. Reykon)                                   52
# Hijo de Su Madre                                                 61
# Lento                                                            65
# Dicen                                                            77
# BEBE                                                             95
# I Like It                                                        95
# Zooted (feat. French Montana & Farruko)                          74
# Havana - Remix                                                   77
# Pum Pum                                                          45
# ...                                                             ...
# Part One - Hey, No Pressure                                      49
# I'm Caving In                                                    36
# Two High                                                         22
# I Need Never Get Old                                             61
# Leavin'                                                          40
# Golden Dandelions                                                49
# Your Love Could Start a War                                       5
# Where's Your Money                                               41
# The World Ender                                                  51
# Pretty Pimpin                                                    67
# Trouble                                                          43
# Daisy                                                             3
# Jackie and Wilson                                                47
# The Less I Know The Better                                       82
# Man On Fire                                                      41
# Sedona                                                           69
# Run                                                              55
# Expectations                                                     44
# Lost The Feeling                                                  3
# Everything Is Alright                                            22
# Jumpstarting                                                     30
# Down by the River                                                34
# Thunder                                                          45
# The Wanting                                                       9
# Lost on You                                                      25
# Around The World                                                 64
# Hot Blood                                                        63
# Wall Of Glass                                                    59
# Get Out                                                          23
# These Days                                                       38
#
#                                                     song_duration_ms  \
# song_name
# MIA (feat. Drake)                                             210367
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)                212500
# White Boi                                                     185282
# Just Wanna Love You (feat. J. Balvin)                         199230
# Beautiful (feat. Camila Cabello)                              180000
# Celoso                                                        179693
# Good Vibes                                                    235720
# Real Friends                                                  223583
# Blah                                                  0.1240    -4.632
# Love N Hennessy REMIX (feat. 2 Chainz & Nicky Jam)    0.0804    -7.569
# Mi Infinita                                           0.1100    -7.555
# Coqueta                                               0.1940   -10.558
# Sola                                                  0.1010   -10.273
# Nuestro Planeta (feat. Reykon)                        0.0756    -6.466
# Hijo de Su Madre                                      0.2810    -7.093
# Lento                                                 0.1030    -5.260
# Dicen                                                 0.2450    -5.719
# BEBE                                                  0.1250    -3.559
# I Like It                                             0.3720    -3.998
# Zooted (feat. French Montana & Farruko)               0.2750    -5.139
# Havana - Remix                                        0.1330    -4.036
# Pum Pum                                               0.1200    -1.490
# ...                                                      ...       ...
# Part One - Hey, No Pressure                           0.1020    -7.707
# I'm Caving In                                         0.2050    -8.078
# Two High                                              0.1180    -5.153
# I Need Never Get Old                                  0.0811    -5.565
# Leavin'                                               0.1120    -5.696
# Golden Dandelions                                     0.1040    -6.002
# Your Love Could Start a War                           0.3430    -3.305
# Where's Your Money                                    0.1170    -5.191
# The World Ender                                       0.8040    -5.600
# Pretty Pimpin                                         0.0903    -9.081
# Trouble                                               0.3830    -5.465
# Daisy                                                 0.0872    -4.013
# Jackie and Wilson                                     0.0937    -4.202
# The Less I Know The Better                            0.1670    -4.083
# Man On Fire                                           0.1440    -4.488
# Sedona                                                0.1120    -7.513
# Run                                                   0.1390    -5.621
# Expectations                                          0.0659    -6.459
# Lost The Feeling                                      0.1010    -4.529
# Everything Is Alright                                 0.1020    -4.180
# Jumpstarting                                          0.3400    -3.639
# Down by the River                                     0.0899    -8.413
# Thunder                                               0.1300    -2.715
# The Wanting                                           0.0553    -4.298
# Lost on You                                           0.0918    -6.126
# Around The World                                      0.3510    -5.847
# Hot Blood                                             0.0962    -3.173
# Wall Of Glass                                         0.2960    -4.469
# Get Out                                               0.1390    -5.957
# These Days                                            0.1900    -5.410
#
#                                                     audio_mode  speechiness  \
# song_name
# MIA (feat. Drake)                                            0       0.0544
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)               0       0.2290
# White Boi                                                    1       0.0520
# Just Wanna Love You (feat. J. Balvin)                        1       0.0540
# Beautiful (feat. Camila Cabello)                             1       0.0337
# Celoso                                                       0       0.1070
# Good Vibes                                                   1       0.0797
# Real Friends                                                 0       0.0969
# Pa La Calle                                                  1       0.1310
# Pa Mí                                                        0       0.3180
# Wake Up in the Sky                                           0       0.0485
# Está Rico                                                    0       0.2830
# Banana Clip - Spanish Version                                0       0.1200
# YAKWTFGO (feat. Kali Uchis)                                  0       0.1390
# Come With Me                                                 1       0.0460
# Como Si Na                                                   0       0.1770
# Blah                                                         0       0.2000
# Love N Hennessy REMIX (feat. 2 Chainz & Nicky Jam)           0       0.4510
# Mi Infinita                                                  1       0.0485
# Coqueta                                                      1       0.0302
# Sola                                                         1       0.0890
# Nuestro Planeta (feat. Reykon)                               0       0.0625
# Hijo de Su Madre                                             1       0.1490
# Lento                                                        0       0.1920
# Dicen                                                        0       0.1380
# BEBE                                                         1       0.1090
# I Like It                                                    0       0.1290
# Zooted (feat. French Montana & Farruko)                      1       0.1030
# Golden Dandelions                                   Rockin' Vibes   Rock
# Your Love Could Start a War                         Rockin' Vibes   Rock
# Where's Your Money                                  Rockin' Vibes   Rock
# The World Ender                                     Rockin' Vibes   Rock
# Pretty Pimpin                                       Rockin' Vibes   Rock
# Trouble                                             Rockin' Vibes   Rock
# Daisy                                               Rockin' Vibes   Rock
# Jackie and Wilson                                   Rockin' Vibes   Rock
# The Less I Know The Better                          Rockin' Vibes   Rock
# Man On Fire                                         Rockin' Vibes   Rock
# Sedona                                              Rockin' Vibes   Rock
# Run                                                 Rockin' Vibes   Rock
# Expectations                                        Rockin' Vibes   Rock
# Lost The Feeling                                    Rockin' Vibes   Rock
# Everything Is Alright                               Rockin' Vibes   Rock
# Jumpstarting                                        Rockin' Vibes   Rock
# Down by the River                                   Rockin' Vibes   Rock
# Thunder                                             Rockin' Vibes   Rock
# The Wanting                                         Rockin' Vibes   Rock
# Lost on You                                         Rockin' Vibes   Rock
# Around The World                                    Rockin' Vibes   Rock
# Hot Blood                                           Rockin' Vibes   Rock
# Wall Of Glass                                       Rockin' Vibes   Rock
# Get Out                                             Rockin' Vibes   Rock
# These Days                                          Rockin' Vibes   Rock
#
# [6195 rows x 18 columns]

# %%
rock_mode = rock_df.audio_mode.value_counts()
country_mode = country_df.audio_mode.value_counts()
pop_mode = pop_df.audio_mode.value_counts()
alt_mode = alt_df.audio_mode.value_counts()
rap_mode = rap_df.audio_mode.value_counts()
latin_mode = latin_df.audio_mode.value_counts()
electronic_mode = electronic_df.audio_mode.value_counts()

# %%
rock_mode
# Out:
# 1    827
# 0    350
# Name: audio_mode, dtype: int64

# %%
minor = np.array([rock_mode[0], country_mode[0], pop_mode[0], alt_mode[0],rap_mode[0], latin_mode[0], electronic_mode[0]])
minor
# Out:
# array([350,  46, 441, 174, 497, 506, 179], dtype=int64)

# %%
major = np.array([rock_mode[1], country_mode[1], pop_mode[1], alt_mode[1],rap_mode[1], latin_mode[1], electronic_mode[1]])
major
# Out:
# array([827, 628, 781, 515, 490, 588, 173], dtype=int64)

# %%
total_modes = major + minor
total_modes
# Out:
# array([1177,  674, 1222,  689,  987, 1094,  352], dtype=int64)

# %%
genres = ["rock", "country", "pop", "alternative", "rap", "latin", "electronic"]

# %%
sns.set_style("white")
sns.set_context({"figure.figsize": (15, 10)})

#Plot 1 - background - "total" (top) series
ax1 = sns.barplot(x = genres, y = total_modes, color = "red")

#Plot 2 - overlay - "bottom" series
bottom_plot = sns.barplot(x = genres, y = major, color = "#0000A3")


topbar = plt.Rectangle((0,0),1,1,fc="red", edgecolor = 'none')
bottombar = plt.Rectangle((0,0),1,1,fc='#0000A3',  edgecolor = 'none')
l = plt.legend([bottombar, topbar], ['Major', 'Minor'], loc=1, ncol = 2, prop={'size':16})
l.draw_frame(False)

#Optional code - Make plot look nicer
sns.despine(left=True)
bottom_plot.set_ylabel("Song Count")
bottom_plot.set_xlabel("Genres")

#Set fonts to consistent 16pt size
for item in ([bottom_plot.xaxis.label, bottom_plot.yaxis.label] +
             bottom_plot.get_xticklabels() + bottom_plot.get_yticklabels()):
    item.set_fontsize(16)

X = np.array(range(0,7))
for i in X:
    ax1.text(i,major[i]/2, major[i], color='white', ha="center", fontsize = 16, weight = "bold")
    bottom_plot.text(i, major[i] + minor[i]/3.5, minor[i], color ="white", ha = "center", fontsize = 16, weight = "bold")

# %%
#Create column that maps numerical key values to musical notation
conditions = [(all_genres_df['key'] == 0),
              (all_genres_df['key'] == 1),
              (all_genres_df['key'] == 2),
              (all_genres_df['key'] == 3),
              (all_genres_df['key'] == 4),
              (all_genres_df['key'] == 5),
              (all_genres_df['key'] == 6),
              (all_genres_df['key'] == 7),
              (all_genres_df['key'] == 8),
              (all_genres_df['key'] == 9),
              (all_genres_df['key'] == 10),
              (all_genres_df['key'] == 11)]

key_sigs = ["C", "C#", "D", "D#","E", "F", "F#", "G", "G#", "A", "A#", "B"]

all_genres_df['key_note'] = np.select(conditions, key_sigs)
all_genres_df.head()
# Out:
#                                                 song_popularity  \
# song_name
# MIA (feat. Drake)                                            94
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# White Boi                                                    59
# Just Wanna Love You (feat. J. Balvin)                        73
# Beautiful (feat. Camila Cabello)                             94
#
#                                                 song_duration_ms  \
# song_name
# MIA (feat. Drake)                                         210367
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)            212500
# White Boi                                                 185282
# Just Wanna Love You (feat. J. Balvin)                     199230
# Beautiful (feat. Camila Cabello)                          180000
#
#                                                 acousticness  danceability  \
# song_name
# MIA (feat. Drake)                                     0.0143         0.818
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)        0.1530         0.841
# White Boi                                             0.0983         0.830
# Just Wanna Love You (feat. J. Balvin)                 0.0557         0.687
# Beautiful (feat. Camila Cabello)                      0.3460         0.638
#
#                                                 energy  instrumentalness  key  \
# song_name
# MIA (feat. Drake)                                0.540          0.000512    6
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)   0.798          0.000003    1
# White Boi                                        0.497          0.000000    1
# Just Wanna Love You (feat. J. Balvin)            0.766          0.001070   11
# Beautiful (feat. Camila Cabello)                 0.717          0.000000    2
#
#                                                 liveness  loudness  \
# song_name
# MIA (feat. Drake)                                 0.0990    -6.350
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)    0.0618    -4.206
# White Boi                                         0.0906    -6.940
# Just Wanna Love You (feat. J. Balvin)             0.1460    -6.080
# Beautiful (feat. Camila Cabello)                  0.1050    -4.722
#
#                                                 audio_mode  speechiness  \
# song_name
# MIA (feat. Drake)                                        0       0.0544
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)           0       0.2290
# White Boi                                                1       0.0520
# Just Wanna Love You (feat. J. Balvin)                    1       0.0540
# Beautiful (feat. Camila Cabello)                         1       0.0337
#
#                                                   tempo  time_signature  \
# song_name
# MIA (feat. Drake)                                97.064               4
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)   95.948               4
# White Boi                                       127.965               4
# Just Wanna Love You (feat. J. Balvin)            94.973               4
# Beautiful (feat. Camila Cabello)                100.027               4
#
#                                                 audio_valence     artist_name  \
# song_name
# MIA (feat. Drake)                                       0.174       Bad Bunny
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)          0.591        DJ Snake
# White Boi                                               0.634  Dillon Francis
# Just Wanna Love You (feat. J. Balvin)                   0.303        Cris Cab
# Beautiful (feat. Camila Cabello)                        0.249           Bazzi
#
#                                                                                    album_names  \
# song_name
# MIA (feat. Drake)                                                            MIA (feat. Drake)
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)  Taki Taki (with Selena Gomez, Ozuna & Cardi B)
# White Boi                                                                              WUT WUT
# Just Wanna Love You (feat. J. Balvin)                    Just Wanna Love You (feat. J. Balvin)
# Beautiful (feat. Camila Cabello)                              Beautiful (feat. Camila Cabello)
#
#                                                    playlist  Genre key_note
# song_name
# MIA (feat. Drake)                               100% LatinX  Latin       F#
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)  100% LatinX  Latin       C#
# White Boi                                       100% LatinX  Latin       C#
# Just Wanna Love You (feat. J. Balvin)           100% LatinX  Latin        B
# Beautiful (feat. Camila Cabello)                100% LatinX  Latin        D

# %%
genres_minor = all_genres_df[all_genres_df.audio_mode == 0]
genres_major = all_genres_df[all_genres_df.audio_mode == 1]

# %%
minor_valence = pd.pivot_table(genres_minor,values='audio_valence', 
                                           index='key_note', columns='Genre', aggfunc=np.median)
minor_valence
# Out:
# Genre     Alternative  Country  Electronic   Latin     Pop     Rap    Rock
# key_note
# A              0.5500   0.5760      0.5020  0.7320  0.4190  0.6595  0.5435
# A#             0.7400   0.9150      0.3450  0.7450  0.5275  0.5630  0.5850
# B              0.4240   0.5655      0.4555  0.6820  0.4970  0.5760  0.5100
# C              0.6245   0.6150      0.4250  0.7015  0.4970  0.5850  0.5050
# C#             0.6500   0.7120      0.2860  0.7350  0.4690  0.6200  0.5670
# D              0.5830   0.7495      0.6500  0.7240  0.5130  0.4950  0.4880
# D#             0.4400   0.5620      0.5535  0.8685  0.4140  0.5525  0.5530
# E              0.6105   0.7040      0.2990  0.6670  0.4625  0.5160  0.5670
# F              0.5360   0.6625      0.4450  0.7880  0.5920  0.5560  0.5135
# F#             0.6420   0.6755      0.5490  0.7860  0.5650  0.5430  0.5460
# G              0.8140   0.4765      0.5640  0.7700  0.4730  0.5330  0.5160
# G#             0.6080   0.8710      0.3105  0.8400  0.4700  0.6030  0.5390

# %%
sns.set_context({"figure.figsize": (15, 10)})
ax = sns.heatmap(minor_valence, cmap= 'PuOr',annot= True, fmt='0.2', annot_kws={'fontsize':20}, 
                 cbar_kws={'label': 'Positivity'}, vmin =0, vmax = 0.9)
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)


ax.figure.axes[-1].yaxis.label.set_size(20)

plt.yticks(rotation = 0)

plt.title('Do Minor Key Signatures Affect Positivity in Music?',fontsize=30)
plt.ylabel('Key\n',fontsize=20, weight = "bold").set_rotation(90)
plt.xlabel('Genres',fontsize=20, weight = "bold").set_rotation(0)

#Set fonts to consistent 16pt size
for item in ([ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

plt.show()

# %%
major_valence = pd.pivot_table(genres_major,values='audio_valence', 
                                           index='key_note', columns='Genre', aggfunc=np.median)
major_valence
# Out:
# Genre     Alternative  Country  Electronic   Latin     Pop     Rap    Rock
# key_note
# A              0.6505   0.6770      0.4735  0.6845  0.5640  0.4540  0.5490
# A#             0.5710   0.6810      0.3860  0.7360  0.4590  0.4795  0.5190
# B              0.6670   0.6695      0.4390  0.7800  0.5850  0.5865  0.5975
# C              0.5660   0.6855      0.3665  0.7720  0.5590  0.5430  0.5815
# C#             0.5345   0.4770      0.2880  0.7200  0.5410  0.5790  0.6460
# D              0.6670   0.6855      0.2770  0.6745  0.5030  0.4635  0.5270
# D#             0.7290   0.7760      0.5150  0.6970  0.3955  0.6640  0.7165
# E              0.6975   0.6770      0.4500  0.7120  0.4970  0.6520  0.6495
# F              0.5690   0.7140      0.2090  0.7210  0.4880  0.4870  0.5075
# F#             0.4895   0.6955      0.4370  0.7470  0.5140  0.6060  0.5120
# G              0.6270   0.6760      0.3770  0.7525  0.5090  0.5735  0.5850
# G#             0.5515   0.6500      0.4540  0.7770  0.5180  0.4365  0.5170

# %%
sns.set_context({"figure.figsize": (15, 10)})
ax = sns.heatmap(major_valence, cmap= 'PuOr',annot= True, fmt='0.2', annot_kws={'fontsize':20}, 
                 cbar_kws={'label': 'Positivity'}, vmin = 0, vmax = 0.9)
cbar = ax.collections[0].colorbar
cbar.ax.tick_params(labelsize=20)


ax.figure.axes[-1].yaxis.label.set_size(20)

plt.yticks(rotation = 0)

plt.title('Do Major Key Signatures Affect Positivity in Music?',fontsize=30)
plt.ylabel('Key\n',fontsize=20, weight = "bold").set_rotation(90)
plt.xlabel('Genres',fontsize=20, weight = "bold").set_rotation(0)

#Set fonts to consistent 16pt size
for item in ([ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(16)

plt.show()

# %%
sns.set_style('darkgrid')

my_plot = sns.violinplot(x='Genre', y='audio_valence', data=all_genres_df, inner="quartile",alpha=.1)
my_plot = sns.stripplot(x='Genre', y='audio_valence', data=all_genres_df, jitter=0.3,alpha=.4)
plt.show()

# %%
all_genres_df.groupby("")
# Out:
#                                                 song_popularity  \
# song_name
# MIA (feat. Drake)                                            94
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# White Boi                                                    59
# Just Wanna Love You (feat. J. Balvin)                        73
# Beautiful (feat. Camila Cabello)                             94
#
#                                                 song_duration_ms  \
# song_name
# MIA (feat. Drake)                                         210367
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)            212500
# White Boi                                                 185282
# Just Wanna Love You (feat. J. Balvin)                     199230
# Beautiful (feat. Camila Cabello)                          180000
#
#                                                 acousticness  danceability  \
# song_name
# MIA (feat. Drake)                                     0.0143         0.818
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)        0.1530         0.841
# White Boi                                             0.0983         0.830
# Just Wanna Love You (feat. J. Balvin)                 0.0557         0.687
# Beautiful (feat. Camila Cabello)                      0.3460         0.638
#
#                                                 energy  instrumentalness  key  \
# song_name
# MIA (feat. Drake)                                0.540          0.000512    6
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)   0.798          0.000003    1
# White Boi                                        0.497          0.000000    1
# Just Wanna Love You (feat. J. Balvin)            0.766          0.001070   11
# Beautiful (feat. Camila Cabello)                 0.717          0.000000    2
#
#                                                 liveness  loudness  \
# song_name
# MIA (feat. Drake)                                 0.0990    -6.350
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)    0.0618    -4.206
# White Boi                                         0.0906    -6.940
# Just Wanna Love You (feat. J. Balvin)             0.1460    -6.080
# Beautiful (feat. Camila Cabello)                  0.1050    -4.722
#
#                                                 audio_mode  speechiness  \
# song_name
# MIA (feat. Drake)                                        0       0.0544
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)           0       0.2290
# White Boi                                                1       0.0520
# Just Wanna Love You (feat. J. Balvin)                    1       0.0540
# Beautiful (feat. Camila Cabello)                         1       0.0337
#
#                                                   tempo  time_signature  \
# song_name
# MIA (feat. Drake)                                97.064               4
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)   95.948               4
# White Boi                                       127.965               4
# Just Wanna Love You (feat. J. Balvin)            94.973               4
# Beautiful (feat. Camila Cabello)                100.027               4
#
#                                                 audio_valence     artist_name  \
# song_name
# MIA (feat. Drake)                                       0.174       Bad Bunny
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)          0.591        DJ Snake
# White Boi                                               0.634  Dillon Francis
# Just Wanna Love You (feat. J. Balvin)                   0.303        Cris Cab
# Beautiful (feat. Camila Cabello)                        0.249           Bazzi
#
#                                                                                    album_names  \
# song_name
# MIA (feat. Drake)                                                            MIA (feat. Drake)
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)  Taki Taki (with Selena Gomez, Ozuna & Cardi B)
# White Boi                                                                              WUT WUT
# Just Wanna Love You (feat. J. Balvin)                    Just Wanna Love You (feat. J. Balvin)
# Beautiful (feat. Camila Cabello)                              Beautiful (feat. Camila Cabello)
#
#                                                    playlist  Genre key_note
# song_name
# MIA (feat. Drake)                               100% LatinX  Latin       F#
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)  100% LatinX  Latin       C#
# White Boi                                       100% LatinX  Latin       C#
# Just Wanna Love You (feat. J. Balvin)           100% LatinX  Latin        B
# Beautiful (feat. Camila Cabello)                100% LatinX  Latin        D

# %%
#Data frame with only numerical continuous data
numerical_df = all_genres_df.drop(['song_popularity', 'artist_name', 'album_names', 'playlist', 'key_note', 'key', 'audio_mode', 'time_signature'], axis=1)
numerical_df.head()
# Out:
#                                                 song_duration_ms  \
# song_name
# MIA (feat. Drake)                                         210367
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)            212500
# White Boi                                                 185282
# Just Wanna Love You (feat. J. Balvin)                     199230
# Beautiful (feat. Camila Cabello)                          180000
#
#                                                 acousticness  danceability  \
# song_name
# MIA (feat. Drake)                                     0.0143         0.818
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)        0.1530         0.841
# White Boi                                             0.0983         0.830
# Just Wanna Love You (feat. J. Balvin)                 0.0557         0.687
# Beautiful (feat. Camila Cabello)                      0.3460         0.638
#
#                                                 energy  instrumentalness  \
# song_name
# MIA (feat. Drake)                                0.540          0.000512
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)   0.798          0.000003
# White Boi                                        0.497          0.000000
# Just Wanna Love You (feat. J. Balvin)            0.766          0.001070
# Beautiful (feat. Camila Cabello)                 0.717          0.000000
#
#                                                 liveness  loudness  \
# song_name
# MIA (feat. Drake)                                 0.0990    -6.350
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)    0.0618    -4.206
# White Boi                                         0.0906    -6.940
# Just Wanna Love You (feat. J. Balvin)             0.1460    -6.080
# Beautiful (feat. Camila Cabello)                  0.1050    -4.722
#
#                                                 speechiness    tempo  \
# song_name
# MIA (feat. Drake)                                    0.0544   97.064
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)       0.2290   95.948
# White Boi                                            0.0520  127.965
# Just Wanna Love You (feat. J. Balvin)                0.0540   94.973
# Beautiful (feat. Camila Cabello)                     0.0337  100.027
#
#                                                 audio_valence  Genre
# song_name
# MIA (feat. Drake)                                       0.174  Latin
# Taki Taki (with Selena Gomez, Ozuna & Cardi B)          0.591  Latin
# White Boi                                               0.634  Latin
# Just Wanna Love You (feat. J. Balvin)                   0.303  Latin
# Beautiful (feat. Camila Cabello)                        0.249  Latin

# %%
genre_avgs_df = numerical_df.groupby(['Genre']).median()
genre_avgs_df
# Out:
#              song_duration_ms  acousticness  danceability  energy  \
# Genre
# Alternative          222000.0       0.05140        0.5410  0.7300
# Country              178246.0       0.55600        0.6255  0.4580
# Electronic           196351.0       0.08715        0.7080  0.5400
# Latin                229415.5       0.22250        0.7120  0.7210
# Pop                  209516.5       0.13750        0.6480  0.6565
# Rap                  211120.0       0.13000        0.7670  0.6500
# Rock                 220200.0       0.01150        0.5180  0.8340
#
#              instrumentalness  liveness  loudness  speechiness     tempo  \
# Genre
# Alternative          0.000882    0.1300   -7.9790      0.04360  125.0170
# Country              0.000004    0.1220  -10.5985      0.03315  116.0710
# Electronic           0.767500    0.1110   -8.9790      0.06270  122.0515
# Latin                0.000005    0.1195   -6.0390      0.05665  110.3105
# Pop                  0.000005    0.1180   -6.2980      0.04805  115.0210
# Rap                  0.000000    0.1230   -6.9530      0.19700  110.9120
# Rock                 0.000129    0.1360   -5.7100      0.04860  125.3490
#
#              audio_valence
# Genre
# Alternative         0.6120
# Country             0.6835
# Electronic          0.3830
# Latin               0.7360
# Pop                 0.5090
# Rap                 0.5540
# Rock                0.5550

# %%
# basic plot
#genre_avgs_df = np.power(genre_avgs_df,2)
names = genre_avgs_df.index
p1=sns.regplot(data=genre_avgs_df, x="energy", y="danceability", fit_reg=False, marker="o", color="skyblue", scatter_kws={'s':genre_avgs_df["audio_valence"]*10000})
axes = p1.axes
#axes.set_ylim(0.35,0.8)
#axes.set_xlim(0.45,0.8)
# add annotations one by one with a loop
for line in range(0,7):
     p1.text(genre_avgs_df.energy[line], genre_avgs_df.danceability[line], names[line], horizontalalignment='left', size='medium', color='black', weight='semibold')
