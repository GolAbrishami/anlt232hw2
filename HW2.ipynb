# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pandas import DataFrame
import os

#set the working directory
os.chdir('./eff-muckrock_alpr_data_2016-2017/')

path = os.getcwd()
print(path)
# Out:
# C:\Users\edalr\Desktop\school\dataviz\homework\anlt232hw2\eff-muckrock_alpr_data_2016-2017

# %%
data = DataFrame(pd.read_csv("EFF-MuckRock 2016-2017 ALPR DATA.csv"))
col_names = list(data.columns.values)
print(col_names)
# Out:
# ['A. Agency', 'B. State', 'C. Direct Sharing', 'D. NVLS', 'E1. 2016 Detections', 'E2. 2016 Hits', 'F1. 2017 Detections', 'F2. 2017 Hits', 'G1. 2016-2017 Detections', 'G2. 2016-2017 Hits', 'H. All Time Detections', 'H2. All Time Hits', 'R1. Data Sharing Link', 'R2. 2016 Hit Ratio Report', 'R3. 2017 Hit Ratio Report', 'R4. 2016 Detection Report', 'R5. 2016 Hit Report', 'R6. 2017 Detection Report', 'R7. 2017 Hit Report', 'R8. Combined Detection/Hit Data']

# %%
data.head()
# Out:
#                            A. Agency B. State C. Direct Sharing D. NVLS  \
# 0          Acworth Police Department       GA               270       Y
# 1    Alamo Heights Police Department       TX                14       Y
# 2  American Canyon Police Department       CA                27       Y
# 3          Atlanta Police Department       GA                 8     NaN
# 4           Auburn Police Department       CA                68       Y
#
#   E1. 2016 Detections E2. 2016 Hits F1. 2017 Detections F2. 2017 Hits  \
# 0        Not Provided  Not Provided        Not Provided  Not Provided
# 1               1,034  Not Provided             407,825  Not Provided
# 2             786,289           271             638,034           194
# 3        Not Provided  Not Provided         128,555,383       786,580
# 4        Not Provided  Not Provided        Not Provided  Not Provided
#
#   G1. 2016-2017 Detections G2. 2016-2017 Hits H. All Time Detections  \
# ...

# %%
data.iloc[:,0:10]
# Out:
#                                              A. Agency B. State  \
# 0                            Acworth Police Department       GA
# 1                      Alamo Heights Police Department       TX
# 2                    American Canyon Police Department       CA
# 3                            Atlanta Police Department       GA
# 4                             Auburn Police Department       CA
# 5                             Austin Police Department       TX
# 6                  Austin Regional Intelligence Center       TX
# 7                        Bakersfield Police Department       CA
# 8                        Ball Ground Police Department       GA
# 9                        Banks County Sheriff's Office       GA
# 10                         Beachwood Police Department       OH
# 11                      Bell Gardens Police Department       CA
# 12                              Bell Police Department       CA
# 13                     Bernardsville Police Department       NJ
# ...

# %%
descriptions = DataFrame(pd.read_csv("EFF-MuckRock 2016-2017 ALPR DATA - Field Descriptions.csv"))

# %%
decsriptions = descriptions.iloc[:,0:10]
descriptions
# Out:
#         A. Agency                       B. State  \
# 0  Name of agency  State where agency is located
# 1             NaN                            NaN
#
#                                    C. Direct Sharing  \
# 0  Number of agencies listed on the Data Sharing ...
# 1                                                NaN
#
#                                              D. NVLS  \
# 0  National Vehicle Location Service (sometimes r...
# 1                                                NaN
#
#                                  E1. 2016 Detections  \
# 0  Total number of license plate scans (detection...
# 1                                                NaN
#
#                                        E2. 2016 Hits  \
# 0  Total number of times in 2016 a scanned licens...
# 1                                                NaN
#
#                                  F1. 2017 Detections  \
# 0  Number of license plate scans (detections) col...
# ...
